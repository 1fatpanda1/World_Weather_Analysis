# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time module.
import time


from scipy.stats import linregress
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high =90.000, size =2000)
lngs =np.random.uniform(low=-180.000, high =180.000, size =2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
        # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oistins
# Processing Record 2 of Set 1 | okha
# Processing Record 3 of Set 1 | williston
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | huntsville
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | san patricio
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | tonantins
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | ancud
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | egvekinot
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | sweetwater
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | nokha
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | mitsamiouli
# Processing Record 30 of Set 1 | kailua
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | antofagasta
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | bikin
# Processing Record 37 of Set 1 | tuatapere
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | vardo
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | touros
# Processing Record 42 of Set 1 | kayes
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | salym
# Processing Record 45 of Set 1 | bilma
# Processing Record 46 of Set 1 | lusambo
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | coihaique
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | rio grande
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | litovko
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | altay
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | fairbanks
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | saverne
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | zambezi
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | manta
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | qaqortoq
# Processing Record 22 of Set 2 | ulagan
# Processing Record 23 of Set 2 | puerto baquerizo moreno
# Processing Record 24 of Set 2 | labuhan
# Processing Record 25 of Set 2 | mount isa
# Processing Record 26 of Set 2 | chengam
# Processing Record 27 of Set 2 | hamilton
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | hambantota
# Processing Record 33 of Set 2 | grand gaube
# Processing Record 34 of Set 2 | pavlodar
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | crown point
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | autazes
# Processing Record 41 of Set 2 | kalmar
# Processing Record 42 of Set 2 | poopo
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | pervomayskoye
# Processing Record 46 of Set 2 | roros
# Processing Record 47 of Set 2 | mormugao
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | kalabagh
# Processing Record 50 of Set 2 | jalu
# Processing Record 1 of Set 3 | solnechnyy
# Processing Record 2 of Set 3 | bubaque
# Processing Record 3 of Set 3 | brae
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | dourbali
# Processing Record 8 of Set 3 | bali chak
# Processing Record 9 of Set 3 | zhuhai
# Processing Record 10 of Set 3 | road town
# Processing Record 11 of Set 3 | tamboril
# Processing Record 12 of Set 3 | tadine
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | bagdarin
# Processing Record 15 of Set 3 | mainaguri
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | erzin
# Processing Record 19 of Set 3 | quatre cocos
# Processing Record 20 of Set 3 | pirai do sul
# Processing Record 21 of Set 3 | itarema
# Processing Record 22 of Set 3 | beloha
# Processing Record 23 of Set 3 | araceli
# Processing Record 24 of Set 3 | margate
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | causapscal
# Processing Record 31 of Set 3 | dakar
# Processing Record 32 of Set 3 | aden
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | lensk
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | altamont
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | olovyannaya
# Processing Record 40 of Set 3 | qasigiannguit
# Processing Record 41 of Set 3 | marzuq
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | simao
# Processing Record 44 of Set 3 | ribeira brava
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | hokitika
# Processing Record 48 of Set 3 | alice springs
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 4 | airai
# Processing Record 2 of Set 4 | matay
# Processing Record 3 of Set 4 | aloleng
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | khandbari
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | college
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | zavetnoye
# Processing Record 11 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | yerbogachen
# Processing Record 16 of Set 4 | faya
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | yar-sale
# Processing Record 19 of Set 4 | namanyere
# Processing Record 20 of Set 4 | avallon
# Processing Record 21 of Set 4 | pringsewu
# Processing Record 22 of Set 4 | limoux
# Processing Record 23 of Set 4 | cam ranh
# Processing Record 24 of Set 4 | cayenne
# Processing Record 25 of Set 4 | sistranda
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | kuytun
# Processing Record 28 of Set 4 | ostrov
# Processing Record 29 of Set 4 | chumikan
# Processing Record 30 of Set 4 | lethem
# Processing Record 31 of Set 4 | ciudad bolivar
# Processing Record 32 of Set 4 | klimovsk
# Processing Record 33 of Set 4 | mopti
# Processing Record 34 of Set 4 | lompoc
# Processing Record 35 of Set 4 | viterbo
# Processing Record 36 of Set 4 | hvittingfoss
# Processing Record 37 of Set 4 | requena
# Processing Record 38 of Set 4 | devli
# Processing Record 39 of Set 4 | fukue
# Processing Record 40 of Set 4 | sakaiminato
# Processing Record 41 of Set 4 | eltham
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | puerto cabello
# Processing Record 45 of Set 4 | inyonga
# Processing Record 46 of Set 4 | statesville
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | korla
# Processing Record 50 of Set 4 | bafia
# Processing Record 1 of Set 5 | garowe
# Processing Record 2 of Set 5 | akyab
# Processing Record 3 of Set 5 | monchegorsk
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | davenda
# Processing Record 6 of Set 5 | vilhena
# Processing Record 7 of Set 5 | belaya gora
# Processing Record 8 of Set 5 | tabas
# Processing Record 9 of Set 5 | sungaipenuh
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | kutahya
# Processing Record 12 of Set 5 | pemangkat
# Processing Record 13 of Set 5 | saurimo
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | ponnani
# Processing Record 16 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | bara
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | port-de-bouc
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | shitanjing
# Processing Record 24 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | iwaki
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | bredasdorp
# Processing Record 29 of Set 5 | pimentel
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | aklavik
# Processing Record 32 of Set 5 | ojhar
# Processing Record 33 of Set 5 | corumba
# Processing Record 34 of Set 5 | leshukonskoye
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | daru
# Processing Record 39 of Set 5 | bystrzyca klodzka
# Processing Record 40 of Set 5 | batemans bay
# Processing Record 41 of Set 5 | normandin
# Processing Record 42 of Set 5 | port-gentil
# Processing Record 43 of Set 5 | jagadhri
# Processing Record 44 of Set 5 | maragogi
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | maldonado
# Processing Record 47 of Set 5 | tolga
# Processing Record 48 of Set 5 | bengkulu
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | fare
# Processing Record 1 of Set 6 | dunedin
# Processing Record 2 of Set 6 | ninotsminda
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | santa isabel do rio negro
# Processing Record 5 of Set 6 | trinidad
# Processing Record 6 of Set 6 | nauchnyy gorodok
# Processing Record 7 of Set 6 | kenora
# Processing Record 8 of Set 6 | forbes
# Processing Record 9 of Set 6 | great falls
# Processing Record 10 of Set 6 | lata
# Processing Record 11 of Set 6 | loandjili
# Processing Record 12 of Set 6 | tateyama
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | olafsvik
# Processing Record 15 of Set 6 | ossora
# Processing Record 16 of Set 6 | sakakah
# Processing Record 17 of Set 6 | platteville
# Processing Record 18 of Set 6 | sterling
# Processing Record 19 of Set 6 | liverpool
# Processing Record 20 of Set 6 | moose factory
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | dombarovskiy
# Processing Record 25 of Set 6 | peniche
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | the valley
# Processing Record 28 of Set 6 | mangan
# Processing Record 29 of Set 6 | coruripe
# Processing Record 30 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 6 | glendive
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | basyanovskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | port keats
# Processing Record 36 of Set 6 | sechura
# Processing Record 37 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 6 | omaruru
# Processing Record 39 of Set 6 | celestun
# Processing Record 40 of Set 6 | bukama
# Processing Record 41 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 42 of Set 6 | srednekolymsk
# Processing Record 43 of Set 6 | la paz
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | yerofey pavlovich
# Processing Record 46 of Set 6 | urumqi
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | puerto madryn
# Processing Record 49 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 6 | kisanga
# Processing Record 1 of Set 7 | tonj
# Processing Record 2 of Set 7 | kikwit
# Processing Record 3 of Set 7 | mutare
# Processing Record 4 of Set 7 | pitimbu
# Processing Record 5 of Set 7 | kloulklubed
# Processing Record 6 of Set 7 | paita
# Processing Record 7 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 7 | mezen
# Processing Record 9 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 10 of Set 7 | semey
# Processing Record 11 of Set 7 | muskogee
# Processing Record 12 of Set 7 | iquique
# Processing Record 13 of Set 7 | turbat
# Processing Record 14 of Set 7 | lincoln
# Processing Record 15 of Set 7 | mumford
# Processing Record 16 of Set 7 | otjimbingwe
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | pocri
# Processing Record 19 of Set 7 | wodonga
# Processing Record 20 of Set 7 | tautira
# Processing Record 21 of Set 7 | kiyasovo
# Processing Record 22 of Set 7 | arcachon
# Processing Record 23 of Set 7 | malakal
# Processing Record 24 of Set 7 | kathmandu
# Processing Record 25 of Set 7 | kahului
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | malanje
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | novoilinsk
# Processing Record 30 of Set 7 | oskemen
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | tabou
# Processing Record 33 of Set 7 | ugoofaaru
# Processing Record 34 of Set 7 | sulangan
# Processing Record 35 of Set 7 | rancho palos verdes
# Processing Record 36 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | arlit
# Processing Record 39 of Set 7 | yakima
# Processing Record 40 of Set 7 | leningradskiy
# Processing Record 41 of Set 7 | necochea
# Processing Record 42 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 43 of Set 7 | bunbury
# Processing Record 44 of Set 7 | mgachi
# Processing Record 45 of Set 7 | kosum phisai
# Processing Record 46 of Set 7 | kang
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | odweyne
# Processing Record 49 of Set 7 | keti bandar
# Processing Record 50 of Set 7 | filingue
# Processing Record 1 of Set 8 | domoni
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | maniitsoq
# Processing Record 4 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 8 | novyy urengoy
# Processing Record 6 of Set 8 | conceicao do araguaia
# Processing Record 7 of Set 8 | palmer
# Processing Record 8 of Set 8 | dum duma
# Processing Record 9 of Set 8 | bahia blanca
# Processing Record 10 of Set 8 | camacha
# Processing Record 11 of Set 8 | flin flon
# Processing Record 12 of Set 8 | vestmannaeyjar
# Processing Record 13 of Set 8 | saryg-sep
# Processing Record 14 of Set 8 | brahmapuri
# City not found. Skipping...
# Processing Record 15 of Set 8 | constantine
# Processing Record 16 of Set 8 | san luis
# Processing Record 17 of Set 8 | taltal
# Processing Record 18 of Set 8 | la asuncion
# Processing Record 19 of Set 8 | kushiro
# Processing Record 20 of Set 8 | san policarpo
# Processing Record 21 of Set 8 | spornoye
# Processing Record 22 of Set 8 | sabang
# Processing Record 23 of Set 8 | thompson
# Processing Record 24 of Set 8 | seoul
# Processing Record 25 of Set 8 | denpasar
# Processing Record 26 of Set 8 | raahe
# Processing Record 27 of Set 8 | usinsk
# Processing Record 28 of Set 8 | karpathos
# Processing Record 29 of Set 8 | chissamba
# Processing Record 30 of Set 8 | langres
# Processing Record 31 of Set 8 | liaqatabad
# Processing Record 32 of Set 8 | tottori
# Processing Record 33 of Set 8 | rockland
# Processing Record 34 of Set 8 | gornopravdinsk
# Processing Record 35 of Set 8 | sri aman
# Processing Record 36 of Set 8 | acapulco
# Processing Record 37 of Set 8 | yongan
# Processing Record 38 of Set 8 | odesskoye
# Processing Record 39 of Set 8 | nargana
# Processing Record 40 of Set 8 | te anau
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | port-cartier
# Processing Record 43 of Set 8 | pauini
# Processing Record 44 of Set 8 | terrell
# Processing Record 45 of Set 8 | kimbe
# Processing Record 46 of Set 8 | voh
# Processing Record 47 of Set 8 | thongwa
# Processing Record 48 of Set 8 | villa altagracia
# Processing Record 49 of Set 8 | bonavista
# Processing Record 50 of Set 8 | ratnagiri
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | broken hill
# Processing Record 3 of Set 9 | lasa
# Processing Record 4 of Set 9 | lodja
# Processing Record 5 of Set 9 | kyren
# Processing Record 6 of Set 9 | dzhebariki-khaya
# Processing Record 7 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 9 | roma
# Processing Record 9 of Set 9 | shelburne
# Processing Record 10 of Set 9 | iberia
# Processing Record 11 of Set 9 | reo
# Processing Record 12 of Set 9 | hasaki
# Processing Record 13 of Set 9 | lazurne
# Processing Record 14 of Set 9 | mutoko
# Processing Record 15 of Set 9 | belmonte
# Processing Record 16 of Set 9 | olga
# Processing Record 17 of Set 9 | miri
# Processing Record 18 of Set 9 | desur
# Processing Record 19 of Set 9 | ust-maya
# Processing Record 20 of Set 9 | sibolga
# Processing Record 21 of Set 9 | turka
# Processing Record 22 of Set 9 | mount gambier
# Processing Record 23 of Set 9 | minudasht
# Processing Record 24 of Set 9 | bull savanna
# Processing Record 25 of Set 9 | platonovka
# Processing Record 26 of Set 9 | rocha
# Processing Record 27 of Set 9 | metehara
# City not found. Skipping...
# Processing Record 28 of Set 9 | teguldet
# Processing Record 29 of Set 9 | taoudenni
# Processing Record 30 of Set 9 | ust-nera
# Processing Record 31 of Set 9 | upernavik
# Processing Record 32 of Set 9 | ubajara
# Processing Record 33 of Set 9 | ajdabiya
# Processing Record 34 of Set 9 | provideniya
# Processing Record 35 of Set 9 | mari
# Processing Record 36 of Set 9 | zaragoza
# Processing Record 37 of Set 9 | tarhunah
# City not found. Skipping...
# Processing Record 38 of Set 9 | talnakh
# Processing Record 39 of Set 9 | saint-augustin
# Processing Record 40 of Set 9 | northam
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | nadym
# Processing Record 43 of Set 9 | jaru
# Processing Record 44 of Set 9 | jacareacanga
# Processing Record 45 of Set 9 | staryy nadym
# Processing Record 46 of Set 9 | itoigawa
# Processing Record 47 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 9 | inuvik
# Processing Record 49 of Set 9 | effingham
# Processing Record 50 of Set 9 | sagua la grande
# Processing Record 1 of Set 10 | houma
# Processing Record 2 of Set 10 | de aar
# Processing Record 3 of Set 10 | seabra
# Processing Record 4 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 10 | bandarbeyla
# Processing Record 6 of Set 10 | thano bula khan
# City not found. Skipping...
# Processing Record 7 of Set 10 | mikhaylovka
# Processing Record 8 of Set 10 | bud
# Processing Record 9 of Set 10 | waipawa
# Processing Record 10 of Set 10 | iturama
# Processing Record 11 of Set 10 | pilar
# Processing Record 12 of Set 10 | yaan
# Processing Record 13 of Set 10 | severnoye
# Processing Record 14 of Set 10 | hualmay
# Processing Record 15 of Set 10 | nhulunbuy
# Processing Record 16 of Set 10 | sao felix do xingu
# Processing Record 17 of Set 10 | kiboga
# Processing Record 18 of Set 10 | geraldton
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | kangaatsiaq
# Processing Record 21 of Set 10 | brigantine
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 10 | kendari
# Processing Record 25 of Set 10 | stendal
# Processing Record 26 of Set 10 | vanavara
# Processing Record 27 of Set 10 | barcelos
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | husavik
# Processing Record 30 of Set 10 | vao
# Processing Record 31 of Set 10 | rengasdengklok
# Processing Record 32 of Set 10 | karpogory
# Processing Record 33 of Set 10 | mirabad
# Processing Record 34 of Set 10 | pisco
# Processing Record 35 of Set 10 | buraydah
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | shellbrook
# Processing Record 38 of Set 10 | zhanaozen
# Processing Record 39 of Set 10 | noumea
# Processing Record 40 of Set 10 | plouzane
# Processing Record 41 of Set 10 | cacoal
# Processing Record 42 of Set 10 | umm kaddadah
# Processing Record 43 of Set 10 | adrar
# Processing Record 44 of Set 10 | ixtapa
# Processing Record 45 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 10 | teya
# Processing Record 47 of Set 10 | blackfoot
# Processing Record 48 of Set 10 | maceio
# Processing Record 49 of Set 10 | jucas
# Processing Record 50 of Set 10 | shenjiamen
# Processing Record 1 of Set 11 | el guayabito
# Processing Record 2 of Set 11 | pochutla
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | christchurch
# Processing Record 5 of Set 11 | winslow
# Processing Record 6 of Set 11 | barcelona
# Processing Record 7 of Set 11 | kulykiv
# Processing Record 8 of Set 11 | nao-me-toque
# City not found. Skipping...
# Processing Record 9 of Set 11 | omsukchan
# Processing Record 10 of Set 11 | southern pines
# Processing Record 11 of Set 11 | pevek
# Processing Record 12 of Set 11 | ouidah
# Processing Record 13 of Set 11 | dongsheng
# Processing Record 14 of Set 11 | phalombe
# Processing Record 15 of Set 11 | vostok
# Processing Record 16 of Set 11 | kjopsvik
# Processing Record 17 of Set 11 | lichtenburg
# Processing Record 18 of Set 11 | nizhniy mamon
# Processing Record 19 of Set 11 | lamar
# Processing Record 20 of Set 11 | kawalu
# Processing Record 21 of Set 11 | omboue
# Processing Record 22 of Set 11 | kilindoni
# Processing Record 23 of Set 11 | udachnyy
# Processing Record 24 of Set 11 | brajrajnagar
# City not found. Skipping...
# Processing Record 25 of Set 11 | mareeba
# Processing Record 26 of Set 11 | bako
# Processing Record 27 of Set 11 | ornskoldsvik
# Processing Record 28 of Set 11 | homer
# Processing Record 29 of Set 11 | kununurra
# Processing Record 30 of Set 11 | conway
# Processing Record 31 of Set 11 | mandan
# Processing Record 32 of Set 11 | kassala
# Processing Record 33 of Set 11 | yeppoon
# Processing Record 34 of Set 11 | bertoua
# Processing Record 35 of Set 11 | galeras
# Processing Record 36 of Set 11 | plaster rock
# Processing Record 37 of Set 11 | luba
# Processing Record 38 of Set 11 | kutum
# Processing Record 39 of Set 11 | mardin
# Processing Record 40 of Set 11 | alofi
# Processing Record 41 of Set 11 | bairiki
# Processing Record 42 of Set 11 | dawei
# Processing Record 43 of Set 11 | unye
# City not found. Skipping...
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | pirgos
# Processing Record 46 of Set 11 | mahajanga
# Processing Record 47 of Set 11 | vilyuysk
# Processing Record 48 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 49 of Set 11 | beberibe
# Processing Record 50 of Set 11 | hearst
# Processing Record 1 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 2 of Set 12 | sao gabriel da cachoeira
# Processing Record 3 of Set 12 | tiznit
# Processing Record 4 of Set 12 | waddan
# Processing Record 5 of Set 12 | mildura
# Processing Record 6 of Set 12 | puerto escondido
# Processing Record 7 of Set 12 | masuguru
# Processing Record 8 of Set 12 | amahai
# Processing Record 9 of Set 12 | cururupu
# Processing Record 10 of Set 12 | mapiripan
# Processing Record 11 of Set 12 | oyon
# Processing Record 12 of Set 12 | zhigalovo
# Processing Record 13 of Set 12 | ilebo
# Processing Record 14 of Set 12 | keuruu
# Processing Record 15 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | kralendijk
# Processing Record 17 of Set 12 | peleduy
# Processing Record 18 of Set 12 | bantry
# Processing Record 19 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 12 | pierre
# Processing Record 21 of Set 12 | klaksvik
# Processing Record 22 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 12 | caravelas
# Processing Record 24 of Set 12 | chipata
# Processing Record 25 of Set 12 | mathbaria
# Processing Record 26 of Set 12 | thohoyandou
# Processing Record 27 of Set 12 | salmon creek
# Processing Record 28 of Set 12 | piacabucu
# Processing Record 29 of Set 12 | sola
# Processing Record 30 of Set 12 | yumen
# Processing Record 31 of Set 12 | santa vitoria
# Processing Record 32 of Set 12 | olinda
# Processing Record 33 of Set 12 | teterow
# Processing Record 34 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 12 | naugarzan
# City not found. Skipping...
# Processing Record 36 of Set 12 | moba
# Processing Record 37 of Set 12 | san cristobal
# Processing Record 38 of Set 12 | oksfjord
# Processing Record 39 of Set 12 | farah
# Processing Record 40 of Set 12 | torbay
# Processing Record 41 of Set 12 | valdemarpils
# Processing Record 42 of Set 12 | chicama
# Processing Record 43 of Set 12 | sao sebastiao
# Processing Record 44 of Set 12 | santa luzia
# Processing Record 45 of Set 12 | jubayl
# City not found. Skipping...
# Processing Record 46 of Set 12 | andenes
# Processing Record 47 of Set 12 | inhambupe
# Processing Record 48 of Set 12 | antigonish
# Processing Record 49 of Set 12 | ardakan
# Processing Record 50 of Set 12 | marystown
# Processing Record 1 of Set 13 | chupa
# Processing Record 2 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 13 | floro
# Processing Record 4 of Set 13 | mecca
# Processing Record 5 of Set 13 | dwarka
# Processing Record 6 of Set 13 | mount vernon
# Processing Record 7 of Set 13 | beringovskiy
# Processing Record 8 of Set 13 | hovd
# Processing Record 9 of Set 13 | comodoro rivadavia
# Processing Record 10 of Set 13 | marrakesh
# Processing Record 11 of Set 13 | buchanan
# Processing Record 12 of Set 13 | capao bonito
# Processing Record 13 of Set 13 | kieta
# Processing Record 14 of Set 13 | meiktila
# Processing Record 15 of Set 13 | gat
# Processing Record 16 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 13 | bandar-e lengeh
# Processing Record 18 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 13 | loa janan
# Processing Record 20 of Set 13 | nosy varika
# Processing Record 21 of Set 13 | sobolevo
# Processing Record 22 of Set 13 | tocopilla
# Processing Record 23 of Set 13 | rio blanco
# Processing Record 24 of Set 13 | cabra
# Processing Record 25 of Set 13 | vanimo
# Processing Record 26 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 13 | bukoba
# Processing Record 28 of Set 13 | surgut
# Processing Record 29 of Set 13 | sao jose da coroa grande
# Processing Record 30 of Set 13 | coahuayana
# Processing Record 31 of Set 13 | nisia floresta
# Processing Record 32 of Set 13 | rawah
# Processing Record 33 of Set 13 | jizan
# Processing Record 34 of Set 13 | menongue
# Processing Record 35 of Set 13 | mucuri
# Processing Record 36 of Set 13 | rawson
# Processing Record 37 of Set 13 | impfondo
# Processing Record 38 of Set 13 | chapais
# Processing Record 39 of Set 13 | tres arroyos
# Processing Record 40 of Set 13 | bucak
# Processing Record 41 of Set 13 | joao pinheiro
# Processing Record 42 of Set 13 | borazjan
# Processing Record 43 of Set 13 | biak
# Processing Record 44 of Set 13 | san vicente
# Processing Record 45 of Set 13 | san andres del rabanedo
# Processing Record 46 of Set 13 | mehamn
# Processing Record 47 of Set 13 | derzhavinsk
# Processing Record 48 of Set 13 | nangomba
# Processing Record 49 of Set 13 | chulumani
# Processing Record 50 of Set 13 | collierville
# Processing Record 1 of Set 14 | badvel
# Processing Record 2 of Set 14 | ramgarh
# Processing Record 3 of Set 14 | gornyak
# Processing Record 4 of Set 14 | gohad
# Processing Record 5 of Set 14 | hervey bay
# Processing Record 6 of Set 14 | isla mujeres
# Processing Record 7 of Set 14 | walla walla
# Processing Record 8 of Set 14 | bafoulabe
# Processing Record 9 of Set 14 | zhangye
# Processing Record 10 of Set 14 | ribas do rio pardo
# Processing Record 11 of Set 14 | agapovka
# Processing Record 12 of Set 14 | bahia honda
# Processing Record 13 of Set 14 | hobyo
# Processing Record 14 of Set 14 | lagoa
# Processing Record 15 of Set 14 | sinnamary
# Processing Record 16 of Set 14 | isoka
# Processing Record 17 of Set 14 | gomel
# Processing Record 18 of Set 14 | praia
# Processing Record 19 of Set 14 | pontes e lacerda
# Processing Record 20 of Set 14 | mosquera
# Processing Record 21 of Set 14 | rodrigues alves
# Processing Record 22 of Set 14 | saint-joseph
# Processing Record 23 of Set 14 | clinton
# Processing Record 24 of Set 14 | saint-francois
# Processing Record 25 of Set 14 | krasnoselkup
# Processing Record 26 of Set 14 | srivardhan
# Processing Record 27 of Set 14 | half moon bay
# Processing Record 28 of Set 14 | mariestad
# Processing Record 29 of Set 14 | benicarlo
# Processing Record 30 of Set 14 | gorontalo
# Processing Record 31 of Set 14 | eureka
# Processing Record 32 of Set 14 | constitucion
# Processing Record 33 of Set 14 | meulaboh
# Processing Record 34 of Set 14 | tucumcari
# Processing Record 35 of Set 14 | bendigo
# Processing Record 36 of Set 14 | chilia veche
# Processing Record 37 of Set 14 | tual
# Processing Record 38 of Set 14 | berlevag
# Processing Record 39 of Set 14 | makakilo city
# Processing Record 40 of Set 14 | beira
# Processing Record 41 of Set 14 | slave lake
# Processing Record 42 of Set 14 | guerrero
# Processing Record 43 of Set 14 | laguna
# Processing Record 44 of Set 14 | zabinka
# City not found. Skipping...
# Processing Record 45 of Set 14 | abha
# Processing Record 46 of Set 14 | sembabule
# Processing Record 47 of Set 14 | ulladulla
# Processing Record 48 of Set 14 | dovers
# Processing Record 49 of Set 14 | lorengau
# Processing Record 50 of Set 14 | ures
# Processing Record 1 of Set 15 | zabid
# Processing Record 2 of Set 15 | bonthe
# Processing Record 3 of Set 15 | duartina
# Processing Record 4 of Set 15 | zunyi
# Processing Record 5 of Set 15 | axim
# Processing Record 6 of Set 15 | jeremie
# Processing Record 7 of Set 15 | sao joao da barra
# Processing Record 8 of Set 15 | tatarsk
# Processing Record 9 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 15 | haukipudas
# Processing Record 11 of Set 15 | tianpeng
# Processing Record 12 of Set 15 | hit
# Processing Record 13 of Set 15 | muriwai beach
# Processing Record 14 of Set 15 | butembo
# Processing Record 15 of Set 15 | yilan
# Processing Record 16 of Set 15 | aykhal
# Processing Record 17 of Set 15 | macusani
# Processing Record 18 of Set 15 | nicoya
# Processing Record 19 of Set 15 | funtua
# Processing Record 20 of Set 15 | samana
# Processing Record 21 of Set 15 | san quintin
# Processing Record 22 of Set 15 | ust-kuyga
# Processing Record 23 of Set 15 | nyuksenitsa
# Processing Record 24 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 15 | iralaya
# Processing Record 26 of Set 15 | sabalgarh
# Processing Record 27 of Set 15 | warwick
# Processing Record 28 of Set 15 | ermelo
# Processing Record 29 of Set 15 | mangrol
# Processing Record 30 of Set 15 | kudahuvadhoo
# Processing Record 31 of Set 15 | elizabeth city
# Processing Record 32 of Set 15 | panaba
# Processing Record 33 of Set 15 | nizhniy tsasuchey
# Processing Record 34 of Set 15 | isangel
# Processing Record 35 of Set 15 | cehegin
# Processing Record 36 of Set 15 | le port
# Processing Record 37 of Set 15 | nouadhibou
# Processing Record 38 of Set 15 | praya
# Processing Record 39 of Set 15 | zeerust
# Processing Record 40 of Set 15 | zheleznodorozhnyy
# Processing Record 41 of Set 15 | moyo
# Processing Record 42 of Set 15 | eirunepe
# Processing Record 43 of Set 15 | wangqing
# Processing Record 44 of Set 15 | joniskis
# Processing Record 45 of Set 15 | piltene
# Processing Record 46 of Set 15 | launceston
# Processing Record 47 of Set 15 | maumere
# Processing Record 48 of Set 15 | nyurba
# Processing Record 49 of Set 15 | bodden town
# Processing Record 50 of Set 15 | namibe
# Processing Record 1 of Set 16 | muisne
# Processing Record 2 of Set 16 | ponta delgada
# Processing Record 3 of Set 16 | podosinovets
# Processing Record 4 of Set 16 | shush
# Processing Record 5 of Set 16 | gamba
# Processing Record 6 of Set 16 | eyemouth
# Processing Record 7 of Set 16 | santa rosa
# Processing Record 8 of Set 16 | pakxan
# Processing Record 9 of Set 16 | fuquene
# Processing Record 10 of Set 16 | chaman
# Processing Record 11 of Set 16 | emerald
# Processing Record 12 of Set 16 | rudbar
# Processing Record 13 of Set 16 | carcassonne
# Processing Record 14 of Set 16 | estelle
# Processing Record 15 of Set 16 | baykit
# Processing Record 16 of Set 16 | cabedelo
# Processing Record 17 of Set 16 | la palma
# Processing Record 18 of Set 16 | tetchea
# City not found. Skipping...
# Processing Record 19 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 16 | rongcheng
# Processing Record 21 of Set 16 | fort frances
# Processing Record 22 of Set 16 | pirpirituba
# Processing Record 23 of Set 16 | najran
# Processing Record 24 of Set 16 | igarka
# Processing Record 25 of Set 16 | whyalla
# Processing Record 26 of Set 16 | kynsperk nad ohri
# Processing Record 27 of Set 16 | nebolchi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Oistins      BB  13.0667  -59.5333     80.69        74
# 1                 Okha      RU  53.5739  142.9478     63.72        70
# 2            Williston      US  48.1470 -103.6180     66.31        57
# 3          Yellowknife      CA  62.4560 -114.3525     66.72        63
# 4           Huntsville      US  34.7304  -86.5861     84.45        71
# ..                 ...     ...      ...       ...       ...       ...
# 716             Najran      SA  17.4924   44.1277     81.91        45
# 717             Igarka      RU  67.4667   86.5833     61.38        69
# 718            Whyalla      AU -33.0333  137.5833     60.06        38
# 719  Kynsperk Nad Ohri      CZ  50.1189   12.5303     55.38        83
# 720           Nebolchi      RU  59.1239   33.3454     59.04        97
#
#      Cloudiness  Wind Speed Current Description
# 0            40       19.57    scattered clouds
# 1            28       13.69    scattered clouds
# 2             7        5.39           clear sky
# 3            75       11.99       broken clouds
# 4             0       10.00           clear sky
# ..          ...         ...                 ...
# 716          93        1.81     overcast clouds
# 717          94       11.63     overcast clouds
# 718          27        0.67    scattered clouds
# 719          89        4.07     overcast clouds
# 720         100        2.89     overcast clouds
#
# [721 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
