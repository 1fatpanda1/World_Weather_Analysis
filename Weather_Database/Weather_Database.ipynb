# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time module.
import time


from scipy.stats import linregress
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high =90.000, size =2000)
lngs =np.random.uniform(low=-180.000, high =180.000, size =2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
        # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | norden
# Processing Record 6 of Set 1 | lichtenfels
# Processing Record 7 of Set 1 | vilyuysk
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | ingham
# Processing Record 10 of Set 1 | kirando
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | mamlyutka
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | kosa
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | portland
# Processing Record 22 of Set 1 | sterlitamak
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | pangnirtung
# Processing Record 29 of Set 1 | kuala lipis
# Processing Record 30 of Set 1 | la uribe
# City not found. Skipping...
# Processing Record 31 of Set 1 | medvedka
# Processing Record 32 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | manono
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | igrim
# Processing Record 38 of Set 1 | champerico
# Processing Record 39 of Set 1 | tiznit
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | mountain home
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | lavrentiya
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | kenai
# Processing Record 1 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | never
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | clyde river
# Processing Record 6 of Set 2 | seoul
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | dickinson
# Processing Record 9 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 2 | mnogovershinnyy
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | puerto escondido
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | kaupanger
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | chongwe
# Processing Record 19 of Set 2 | sambava
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | ipixuna
# Processing Record 22 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 2 | afsin
# Processing Record 24 of Set 2 | port macquarie
# Processing Record 25 of Set 2 | chiang kham
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | bubaque
# Processing Record 28 of Set 2 | culipapa
# City not found. Skipping...
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | yulara
# Processing Record 32 of Set 2 | bafia
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | talwandi bhai
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | itoman
# Processing Record 38 of Set 2 | beloha
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | beroroha
# Processing Record 42 of Set 2 | turtkul
# City not found. Skipping...
# Processing Record 43 of Set 2 | buala
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | maumere
# Processing Record 47 of Set 2 | zyryanovsk
# Processing Record 48 of Set 2 | ribeira brava
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | bilma
# Processing Record 2 of Set 3 | tuatapere
# Processing Record 3 of Set 3 | kaeo
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | port-gentil
# Processing Record 6 of Set 3 | flin flon
# Processing Record 7 of Set 3 | terra santa
# Processing Record 8 of Set 3 | correntina
# Processing Record 9 of Set 3 | half moon bay
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | sile
# Processing Record 16 of Set 3 | cabedelo
# Processing Record 17 of Set 3 | daru
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | miles city
# Processing Record 20 of Set 3 | lesnoye
# Processing Record 21 of Set 3 | les escoumins
# Processing Record 22 of Set 3 | moose factory
# Processing Record 23 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | jirlau
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | karasburg
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | kolaras
# Processing Record 31 of Set 3 | atambua
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | eureka
# Processing Record 34 of Set 3 | codrington
# Processing Record 35 of Set 3 | krasnovishersk
# Processing Record 36 of Set 3 | perth
# Processing Record 37 of Set 3 | vanimo
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | nishihara
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | bontang
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | klaksvik
# Processing Record 44 of Set 3 | dibaya
# City not found. Skipping...
# Processing Record 45 of Set 3 | del rio
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | harboore
# Processing Record 48 of Set 3 | gat
# Processing Record 49 of Set 3 | vallenar
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | grand forks
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | fairbanks
# Processing Record 4 of Set 4 | pontes e lacerda
# Processing Record 5 of Set 4 | mahon
# Processing Record 6 of Set 4 | camacha
# Processing Record 7 of Set 4 | tura
# Processing Record 8 of Set 4 | novikovo
# Processing Record 9 of Set 4 | kieta
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | chokurdakh
# Processing Record 12 of Set 4 | subate
# Processing Record 13 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 4 | sawtell
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | darab
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | leningradskiy
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | pemangkat
# Processing Record 22 of Set 4 | brigantine
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | sao jose da coroa grande
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | hovin
# Processing Record 28 of Set 4 | chitungwiza
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | moerai
# Processing Record 31 of Set 4 | goderich
# Processing Record 32 of Set 4 | hobart
# Processing Record 33 of Set 4 | talara
# Processing Record 34 of Set 4 | vallentuna
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | gravdal
# Processing Record 37 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | shepsi
# Processing Record 40 of Set 4 | baruun-urt
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | tabira
# Processing Record 43 of Set 4 | tautira
# Processing Record 44 of Set 4 | senanga
# Processing Record 45 of Set 4 | abbotsford
# Processing Record 46 of Set 4 | omboue
# Processing Record 47 of Set 4 | kirakira
# Processing Record 48 of Set 4 | tarko-sale
# Processing Record 49 of Set 4 | zhigansk
# Processing Record 50 of Set 4 | palana
# Processing Record 1 of Set 5 | mulchen
# Processing Record 2 of Set 5 | silivainiotika
# City not found. Skipping...
# Processing Record 3 of Set 5 | sibolga
# Processing Record 4 of Set 5 | pevek
# Processing Record 5 of Set 5 | gouyave
# Processing Record 6 of Set 5 | wajir
# Processing Record 7 of Set 5 | candolim
# Processing Record 8 of Set 5 | hangha
# Processing Record 9 of Set 5 | akdepe
# Processing Record 10 of Set 5 | elban
# Processing Record 11 of Set 5 | kamenka
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | iqaluit
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | sao francisco do sul
# Processing Record 16 of Set 5 | jutai
# Processing Record 17 of Set 5 | fukue
# Processing Record 18 of Set 5 | santa rosa
# Processing Record 19 of Set 5 | dabat
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | mogadishu
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | pokrovsk
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | namibe
# Processing Record 26 of Set 5 | teacapan
# Processing Record 27 of Set 5 | kysyl-syr
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | stromness
# Processing Record 30 of Set 5 | iringa
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | provideniya
# Processing Record 33 of Set 5 | loiza
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | cedar city
# Processing Record 36 of Set 5 | sistranda
# Processing Record 37 of Set 5 | baykit
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | maloy
# Processing Record 42 of Set 5 | utraula
# Processing Record 43 of Set 5 | saint george
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | viedma
# Processing Record 46 of Set 5 | glace bay
# Processing Record 47 of Set 5 | valparaiso
# Processing Record 48 of Set 5 | padang
# Processing Record 49 of Set 5 | tuktoyaktuk
# Processing Record 50 of Set 5 | limbang
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | los llanos de aridane
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | kulhudhuffushi
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | toora-khem
# Processing Record 7 of Set 6 | segovia
# Processing Record 8 of Set 6 | burica
# City not found. Skipping...
# Processing Record 9 of Set 6 | naze
# Processing Record 10 of Set 6 | broome
# Processing Record 11 of Set 6 | itaueira
# Processing Record 12 of Set 6 | rupert
# Processing Record 13 of Set 6 | yellowknife
# Processing Record 14 of Set 6 | mao
# Processing Record 15 of Set 6 | aykhal
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | cervo
# Processing Record 18 of Set 6 | saint-joseph
# Processing Record 19 of Set 6 | tudela
# Processing Record 20 of Set 6 | bengkulu
# Processing Record 21 of Set 6 | adrar
# Processing Record 22 of Set 6 | bowen
# Processing Record 23 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 24 of Set 6 | veraval
# Processing Record 25 of Set 6 | ryotsu
# Processing Record 26 of Set 6 | sur
# Processing Record 27 of Set 6 | mahajanga
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | mae sot
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | havelock
# Processing Record 32 of Set 6 | pitimbu
# Processing Record 33 of Set 6 | berlevag
# Processing Record 34 of Set 6 | kyaikto
# Processing Record 35 of Set 6 | komatipoort
# Processing Record 36 of Set 6 | westport
# Processing Record 37 of Set 6 | grindavik
# Processing Record 38 of Set 6 | ailigandi
# Processing Record 39 of Set 6 | port lincoln
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | abidjan
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | paranaiba
# Processing Record 44 of Set 6 | fontem
# Processing Record 45 of Set 6 | santander jimenez
# Processing Record 46 of Set 6 | fayaoue
# Processing Record 47 of Set 6 | camocim
# Processing Record 48 of Set 6 | uusikaupunki
# Processing Record 49 of Set 6 | evensk
# Processing Record 50 of Set 6 | santa cruz
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | swan hill
# Processing Record 3 of Set 7 | flinders
# Processing Record 4 of Set 7 | panama city
# Processing Record 5 of Set 7 | cunha
# Processing Record 6 of Set 7 | dawei
# Processing Record 7 of Set 7 | kalmunai
# Processing Record 8 of Set 7 | tessalit
# Processing Record 9 of Set 7 | coihaique
# Processing Record 10 of Set 7 | limoeiro do ajuru
# Processing Record 11 of Set 7 | rio grande
# Processing Record 12 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | naliya
# Processing Record 15 of Set 7 | santiago del estero
# Processing Record 16 of Set 7 | hambantota
# Processing Record 17 of Set 7 | liberal
# Processing Record 18 of Set 7 | georgetown
# Processing Record 19 of Set 7 | dunedin
# Processing Record 20 of Set 7 | genhe
# Processing Record 21 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | elat
# Processing Record 24 of Set 7 | lakatoro
# Processing Record 25 of Set 7 | dingle
# Processing Record 26 of Set 7 | geneva
# Processing Record 27 of Set 7 | zalantun
# Processing Record 28 of Set 7 | balykshi
# Processing Record 29 of Set 7 | suntar
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | sao paulo de olivenca
# Processing Record 32 of Set 7 | tolaga bay
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | mayumba
# Processing Record 35 of Set 7 | preobrazheniye
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | khorixas
# Processing Record 38 of Set 7 | wajid
# Processing Record 39 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 7 | manado
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | faya
# Processing Record 43 of Set 7 | deputatskiy
# Processing Record 44 of Set 7 | maraa
# Processing Record 45 of Set 7 | paamiut
# Processing Record 46 of Set 7 | maldonado
# Processing Record 47 of Set 7 | lethem
# Processing Record 48 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 7 | pahrump
# Processing Record 50 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 1 of Set 8 | pitiquito
# Processing Record 2 of Set 8 | sioux lookout
# Processing Record 3 of Set 8 | manta
# Processing Record 4 of Set 8 | itarema
# Processing Record 5 of Set 8 | vysokogornyy
# Processing Record 6 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 8 | kurumkan
# Processing Record 8 of Set 8 | nome
# Processing Record 9 of Set 8 | kailua
# Processing Record 10 of Set 8 | champasak
# Processing Record 11 of Set 8 | morros
# Processing Record 12 of Set 8 | wilmington
# Processing Record 13 of Set 8 | launceston
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | ulladulla
# Processing Record 16 of Set 8 | xining
# Processing Record 17 of Set 8 | beyneu
# Processing Record 18 of Set 8 | atar
# Processing Record 19 of Set 8 | sergeyevka
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | praia da vitoria
# Processing Record 22 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | lattes
# Processing Record 25 of Set 8 | arandis
# Processing Record 26 of Set 8 | zhuhai
# Processing Record 27 of Set 8 | sabha
# Processing Record 28 of Set 8 | shache
# Processing Record 29 of Set 8 | opuwo
# Processing Record 30 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | orocue
# Processing Record 34 of Set 8 | linjiang
# Processing Record 35 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 8 | kloulklubed
# Processing Record 37 of Set 8 | benguela
# Processing Record 38 of Set 8 | derzhavinsk
# Processing Record 39 of Set 8 | san buenaventura
# Processing Record 40 of Set 8 | pemba
# Processing Record 41 of Set 8 | ormara
# Processing Record 42 of Set 8 | inirida
# Processing Record 43 of Set 8 | voskresenskoye
# Processing Record 44 of Set 8 | umm kaddadah
# Processing Record 45 of Set 8 | mount isa
# Processing Record 46 of Set 8 | de haan
# Processing Record 47 of Set 8 | madras
# Processing Record 48 of Set 8 | edgewater
# Processing Record 49 of Set 8 | leh
# Processing Record 50 of Set 8 | kirknewton
# Processing Record 1 of Set 9 | vanavara
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 4 of Set 9 | chimala
# Processing Record 5 of Set 9 | nhulunbuy
# Processing Record 6 of Set 9 | hovd
# Processing Record 7 of Set 9 | motygino
# Processing Record 8 of Set 9 | wainwright
# Processing Record 9 of Set 9 | penzance
# Processing Record 10 of Set 9 | barcelona
# Processing Record 11 of Set 9 | geraldton
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | aligudarz
# Processing Record 14 of Set 9 | springbok
# Processing Record 15 of Set 9 | khandyga
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | inhambane
# Processing Record 18 of Set 9 | brownfield
# Processing Record 19 of Set 9 | praya
# Processing Record 20 of Set 9 | muravlenko
# Processing Record 21 of Set 9 | asau
# Processing Record 22 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 9 | chany
# Processing Record 24 of Set 9 | kushmurun
# Processing Record 25 of Set 9 | jinchang
# Processing Record 26 of Set 9 | kabale
# Processing Record 27 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 9 | epureni
# Processing Record 29 of Set 9 | narasannapeta
# Processing Record 30 of Set 9 | puerto cabezas
# Processing Record 31 of Set 9 | grand-santi
# Processing Record 32 of Set 9 | kushima
# Processing Record 33 of Set 9 | panguna
# Processing Record 34 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 9 | saldanha
# Processing Record 36 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 9 | haines junction
# Processing Record 38 of Set 9 | nuuk
# Processing Record 39 of Set 9 | puerto narino
# Processing Record 40 of Set 9 | marion
# Processing Record 41 of Set 9 | baoqing
# Processing Record 42 of Set 9 | siocon
# Processing Record 43 of Set 9 | araouane
# Processing Record 44 of Set 9 | raychikhinsk
# Processing Record 45 of Set 9 | abu samrah
# Processing Record 46 of Set 9 | sorong
# Processing Record 47 of Set 9 | rawson
# Processing Record 48 of Set 9 | byron bay
# Processing Record 49 of Set 9 | ternate
# Processing Record 50 of Set 9 | riachao do dantas
# Processing Record 1 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 10 | farkhor
# Processing Record 3 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 10 | tukrah
# Processing Record 5 of Set 10 | katete
# Processing Record 6 of Set 10 | la union
# Processing Record 7 of Set 10 | novotroitsk
# Processing Record 8 of Set 10 | tanete
# Processing Record 9 of Set 10 | luderitz
# Processing Record 10 of Set 10 | poum
# Processing Record 11 of Set 10 | boffa
# Processing Record 12 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 10 | kidal
# Processing Record 14 of Set 10 | coahuayana
# Processing Record 15 of Set 10 | gushikawa
# Processing Record 16 of Set 10 | eyl
# Processing Record 17 of Set 10 | kimbe
# Processing Record 18 of Set 10 | cottonwood heights
# Processing Record 19 of Set 10 | hobyo
# Processing Record 20 of Set 10 | pierre
# Processing Record 21 of Set 10 | yumen
# Processing Record 22 of Set 10 | caraquet
# Processing Record 23 of Set 10 | orange
# Processing Record 24 of Set 10 | maniitsoq
# Processing Record 25 of Set 10 | asilah
# Processing Record 26 of Set 10 | rio tercero
# Processing Record 27 of Set 10 | porto tolle
# Processing Record 28 of Set 10 | garowe
# Processing Record 29 of Set 10 | iralaya
# Processing Record 30 of Set 10 | carndonagh
# Processing Record 31 of Set 10 | minab
# Processing Record 32 of Set 10 | manhush
# Processing Record 33 of Set 10 | ballina
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | vaitape
# Processing Record 36 of Set 10 | kharp
# Processing Record 37 of Set 10 | werda
# Processing Record 38 of Set 10 | mareeba
# Processing Record 39 of Set 10 | ionia
# Processing Record 40 of Set 10 | yuci
# Processing Record 41 of Set 10 | esil
# Processing Record 42 of Set 10 | inta
# Processing Record 43 of Set 10 | kusk
# City not found. Skipping...
# Processing Record 44 of Set 10 | casimiro castillo
# Processing Record 45 of Set 10 | madridejos
# Processing Record 46 of Set 10 | abu kamal
# Processing Record 47 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 10 | kununurra
# Processing Record 49 of Set 10 | agua verde
# Processing Record 50 of Set 10 | zabid
# Processing Record 1 of Set 11 | mitchell
# Processing Record 2 of Set 11 | sarany
# Processing Record 3 of Set 11 | belle glade
# Processing Record 4 of Set 11 | sigli
# Processing Record 5 of Set 11 | zaraza
# Processing Record 6 of Set 11 | freeport
# Processing Record 7 of Set 11 | davila
# Processing Record 8 of Set 11 | tondano
# Processing Record 9 of Set 11 | san jose
# Processing Record 10 of Set 11 | muli
# Processing Record 11 of Set 11 | svelgen
# Processing Record 12 of Set 11 | marmaron
# City not found. Skipping...
# Processing Record 13 of Set 11 | shcholkine
# City not found. Skipping...
# Processing Record 14 of Set 11 | jacareacanga
# Processing Record 15 of Set 11 | chapais
# Processing Record 16 of Set 11 | san cristobal
# Processing Record 17 of Set 11 | kurilsk
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 11 | whitehorse
# Processing Record 21 of Set 11 | thinadhoo
# Processing Record 22 of Set 11 | touros
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | buckeye
# Processing Record 25 of Set 11 | changde
# Processing Record 26 of Set 11 | davenda
# Processing Record 27 of Set 11 | malartic
# Processing Record 28 of Set 11 | pangoa
# Processing Record 29 of Set 11 | ginda
# Processing Record 30 of Set 11 | sirjan
# Processing Record 31 of Set 11 | belyy yar
# Processing Record 32 of Set 11 | sakaiminato
# Processing Record 33 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 11 | ayorou
# Processing Record 35 of Set 11 | spirovo
# Processing Record 36 of Set 11 | bronnoysund
# Processing Record 37 of Set 11 | rolla
# Processing Record 38 of Set 11 | vardo
# Processing Record 39 of Set 11 | tabou
# Processing Record 40 of Set 11 | barcelos
# Processing Record 41 of Set 11 | mamakan
# Processing Record 42 of Set 11 | punta alta
# Processing Record 43 of Set 11 | vieste
# Processing Record 44 of Set 11 | ravar
# Processing Record 45 of Set 11 | tilichiki
# Processing Record 46 of Set 11 | basco
# Processing Record 47 of Set 11 | katherine
# Processing Record 48 of Set 11 | matara
# Processing Record 49 of Set 11 | victoria
# Processing Record 50 of Set 11 | christchurch
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | mednogorsk
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | la spezia
# Processing Record 5 of Set 12 | linhares
# Processing Record 6 of Set 12 | filiates
# Processing Record 7 of Set 12 | makat
# Processing Record 8 of Set 12 | matay
# Processing Record 9 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 12 | koslan
# Processing Record 11 of Set 12 | kerrville
# Processing Record 12 of Set 12 | saint-denis
# Processing Record 13 of Set 12 | fomboni
# Processing Record 14 of Set 12 | necochea
# Processing Record 15 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 12 | havoysund
# Processing Record 17 of Set 12 | nouakchott
# Processing Record 18 of Set 12 | paraiso
# Processing Record 19 of Set 12 | lhokseumawe
# Processing Record 20 of Set 12 | qujing
# Processing Record 21 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 12 | hinton
# Processing Record 23 of Set 12 | mlonggo
# Processing Record 24 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 25 of Set 12 | bitburg
# Processing Record 26 of Set 12 | lasa
# Processing Record 27 of Set 12 | vrede
# Processing Record 28 of Set 12 | redlands
# Processing Record 29 of Set 12 | morondava
# Processing Record 30 of Set 12 | olafsvik
# Processing Record 31 of Set 12 | bandundu
# Processing Record 32 of Set 12 | ayame
# Processing Record 33 of Set 12 | ouidah
# Processing Record 34 of Set 12 | ibra
# Processing Record 35 of Set 12 | isoka
# Processing Record 36 of Set 12 | baherden
# Processing Record 37 of Set 12 | alta floresta
# Processing Record 38 of Set 12 | sao joao da barra
# Processing Record 39 of Set 12 | along
# Processing Record 40 of Set 12 | saquena
# Processing Record 41 of Set 12 | arman
# Processing Record 42 of Set 12 | marsa matruh
# Processing Record 43 of Set 12 | nioro
# Processing Record 44 of Set 12 | nelson bay
# Processing Record 45 of Set 12 | peebles
# Processing Record 46 of Set 12 | elmira
# Processing Record 47 of Set 12 | pafos
# Processing Record 48 of Set 12 | taoudenni
# Processing Record 49 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 12 | tianjin
# Processing Record 1 of Set 13 | wonthaggi
# Processing Record 2 of Set 13 | pingxiang
# Processing Record 3 of Set 13 | yichang
# Processing Record 4 of Set 13 | nicolas bravo
# Processing Record 5 of Set 13 | saint-pierre
# Processing Record 6 of Set 13 | esmeraldas
# Processing Record 7 of Set 13 | teofilo otoni
# Processing Record 8 of Set 13 | yelizovo
# Processing Record 9 of Set 13 | donskoye
# Processing Record 10 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 13 | lata
# Processing Record 12 of Set 13 | salinopolis
# Processing Record 13 of Set 13 | bonfim
# Processing Record 14 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 15 of Set 13 | fortuna
# Processing Record 16 of Set 13 | rundu
# Processing Record 17 of Set 13 | kilindoni
# Processing Record 18 of Set 13 | yaan
# Processing Record 19 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 20 of Set 13 | luanda
# Processing Record 21 of Set 13 | korla
# Processing Record 22 of Set 13 | aguisan
# Processing Record 23 of Set 13 | marsh harbour
# Processing Record 24 of Set 13 | hibbing
# Processing Record 25 of Set 13 | port keats
# Processing Record 26 of Set 13 | ayan
# Processing Record 27 of Set 13 | chernyshevskiy
# Processing Record 28 of Set 13 | tahoua
# Processing Record 29 of Set 13 | chimbote
# Processing Record 30 of Set 13 | weligama
# Processing Record 31 of Set 13 | san francisco del mar
# Processing Record 32 of Set 13 | iberia
# Processing Record 33 of Set 13 | coquimbo
# Processing Record 34 of Set 13 | novyy urengoy
# Processing Record 35 of Set 13 | santa vitoria do palmar
# Processing Record 36 of Set 13 | hervey bay
# Processing Record 37 of Set 13 | ambon
# Processing Record 38 of Set 13 | cabugao
# Processing Record 39 of Set 13 | san
# Processing Record 40 of Set 13 | khandbari
# Processing Record 41 of Set 13 | riyadh
# Processing Record 42 of Set 13 | guerrero negro
# Processing Record 43 of Set 13 | altay
# Processing Record 44 of Set 13 | lazaro cardenas
# Processing Record 45 of Set 13 | jalu
# Processing Record 46 of Set 13 | okha
# Processing Record 47 of Set 13 | hirara
# Processing Record 48 of Set 13 | high level
# Processing Record 49 of Set 13 | qostanay
# Processing Record 50 of Set 13 | sao gabriel da cachoeira
# Processing Record 1 of Set 14 | awbari
# Processing Record 2 of Set 14 | yatou
# Processing Record 3 of Set 14 | roald
# Processing Record 4 of Set 14 | yuanping
# Processing Record 5 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 14 | inuvik
# Processing Record 7 of Set 14 | bording
# Processing Record 8 of Set 14 | saint anthony
# Processing Record 9 of Set 14 | honningsvag
# Processing Record 10 of Set 14 | sabang
# Processing Record 11 of Set 14 | port stanley
# Processing Record 12 of Set 14 | moji-mirim
# City not found. Skipping...
# Processing Record 13 of Set 14 | kruisfontein
# Processing Record 14 of Set 14 | umm lajj
# Processing Record 15 of Set 14 | trincomalee
# Processing Record 16 of Set 14 | comodoro rivadavia
# Processing Record 17 of Set 14 | muskegon
# Processing Record 18 of Set 14 | lensk
# Processing Record 19 of Set 14 | pacific grove
# Processing Record 20 of Set 14 | margate
# Processing Record 21 of Set 14 | mizan teferi
# Processing Record 22 of Set 14 | asmara
# Processing Record 23 of Set 14 | boende
# Processing Record 24 of Set 14 | san andres
# Processing Record 25 of Set 14 | porto novo
# Processing Record 26 of Set 14 | bindura
# Processing Record 27 of Set 14 | tomatlan
# Processing Record 28 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 14 | marshfield
# Processing Record 30 of Set 14 | lufilufi
# Processing Record 31 of Set 14 | varzea da palma
# Processing Record 32 of Set 14 | ust-kuyga
# Processing Record 33 of Set 14 | vostok
# Processing Record 34 of Set 14 | kirkuk
# Processing Record 35 of Set 14 | carbondale
# Processing Record 36 of Set 14 | promyshlennyy
# Processing Record 37 of Set 14 | merauke
# Processing Record 38 of Set 14 | orcopampa
# Processing Record 39 of Set 14 | kangaatsiaq
# Processing Record 40 of Set 14 | benjamin aceval
# Processing Record 41 of Set 14 | gander
# Processing Record 42 of Set 14 | bocas del toro
# Processing Record 43 of Set 14 | consuegra
# Processing Record 44 of Set 14 | ahipara
# Processing Record 45 of Set 14 | almeirim
# Processing Record 46 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 14 | baghdad
# Processing Record 48 of Set 14 | burnie
# Processing Record 49 of Set 14 | krasnoturansk
# Processing Record 50 of Set 14 | kortkeros
# Processing Record 1 of Set 15 | lyubim
# Processing Record 2 of Set 15 | pingliang
# Processing Record 3 of Set 15 | noumea
# Processing Record 4 of Set 15 | mercedes
# Processing Record 5 of Set 15 | hulan
# Processing Record 6 of Set 15 | poya
# Processing Record 7 of Set 15 | awjilah
# Processing Record 8 of Set 15 | lancaster
# Processing Record 9 of Set 15 | puerto ayacucho
# Processing Record 10 of Set 15 | japura
# Processing Record 11 of Set 15 | cap malheureux
# Processing Record 12 of Set 15 | caico
# Processing Record 13 of Set 15 | henties bay
# Processing Record 14 of Set 15 | susuman
# Processing Record 15 of Set 15 | carberry
# Processing Record 16 of Set 15 | bonavista
# Processing Record 17 of Set 15 | ngunguru
# Processing Record 18 of Set 15 | mayo
# Processing Record 19 of Set 15 | isetskoye
# Processing Record 20 of Set 15 | taveta
# Processing Record 21 of Set 15 | piedras amarillas
# City not found. Skipping...
# Processing Record 22 of Set 15 | lingao
# Processing Record 23 of Set 15 | deer lake
# Processing Record 24 of Set 15 | voznesenskaya
# Processing Record 25 of Set 15 | sinnamary
# Processing Record 26 of Set 15 | turukhansk
# Processing Record 27 of Set 15 | ust-nera
# Processing Record 28 of Set 15 | moyale
# Processing Record 29 of Set 15 | sangre grande
# Processing Record 30 of Set 15 | bend
# Processing Record 31 of Set 15 | tortoli
# Processing Record 32 of Set 15 | ajaccio
# Processing Record 33 of Set 15 | aklavik
# Processing Record 34 of Set 15 | tezu
# Processing Record 35 of Set 15 | tamworth
# Processing Record 36 of Set 15 | matagami
# Processing Record 37 of Set 15 | amahai
# Processing Record 38 of Set 15 | hualmay
# Processing Record 39 of Set 15 | ornskoldsvik
# Processing Record 40 of Set 15 | darlawn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Ponta Do Sol      PT  32.6667  -17.1000     72.23        79
# 1        Port Alfred      ZA -33.5906   26.8910     64.04        80
# 2          Hithadhoo      MV  -0.6000   73.0833     82.42        73
# 3    Bambous Virieux      MU -20.3428   57.7575     68.25        88
# 4             Norden      DE  53.6000    7.2000     58.96        65
# ..               ...     ...      ...       ...       ...       ...
# 675         Matagami      CA  49.7502  -77.6328     60.91       100
# 676           Amahai      ID  -3.3333  128.9167     77.77        90
# 677          Hualmay      PE -11.0964  -77.6139     61.77        86
# 678     Ornskoldsvik      SE  63.2909   18.7153     47.35        81
# 679          Darlawn      IN  24.0167   92.9000     78.40        63
#
#      Cloudiness  Wind Speed           Description
# 0             0        5.30             clear sky
# 1            86       19.44       overcast clouds
# 2           100       12.26       overcast clouds
# 3            40        5.75            light rain
# 4            99        6.98       overcast clouds
# ..          ...         ...                   ...
# 675         100        6.91            light rain
# 676          97       10.45  heavy intensity rain
# 677          39       10.69      scattered clouds
# 678          34       12.66      scattered clouds
# 679          97        1.16       overcast clouds
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
